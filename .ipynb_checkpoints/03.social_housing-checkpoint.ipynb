# %% [markdown]
# # Thesis 2024 - 2025
# ## UGBS
# ### Isil Oral
#
# * Project on green gentrification in Vienna through social status index, green spaces, blue areas, and housing prices

# %% [markdown]
# ## Part 3 - Social Housing in Vienna

# %%
from shapely.geometry import box, Point, LineString, Polygon, MultiPolygon
from shapely.ops import unary_union
import geopandas as gpd
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np
import rasterio
from rasterio.mask import mask
from rasterio.plot import show
from rasterio.warp import calculate_default_transform, reproject
from rasterio.enums import Resampling
import osmnx as ox  
import contextily as ctx
from geopy.geocoders import Nominatim  
from geopy.extra.rate_limiter import RateLimiter
import os
# !pip install h3
import h3
import matplotlib.patches as mpatches

# %%
# Get the current working directory
current_path = os.getcwd()

# Define relative paths for data, output, and helper functions
data_in = os.path.join(current_path, "data")       # Folder with input data
output = os.path.join(current_path, "output")      # Folder for saving results
df_dir = os.path.join(current_path, "dataframes")

# %%
# Load any dataframe from that folder
admin_city = gpd.read_file(os.path.join(df_dir, "admin_city_vienna.geojson"))
ugbs_socioecon_census = gpd.read_file(os.path.join(df_dir, "ugbs_socioecon_census_final.geojson"))
urban_green_spaces =gpd.read_file(os.path.join(df_dir, "urban_green_spaces.geojson"))
urban_blue_spaces = gpd.read_file(os.path.join(df_dir, "urban_blue_spaces.geojson"))
apt_features_final = pd.read_csv(os.path.join(df_dir, 'apt_features_final_census.csv'))
# Out:
# Skipping field ways: unsupported OGR type: 1

# %%
# Resource: https://www.wienerwohnen.at/wiener-gemeindebau/gemeindebaubeschreibungen.html
buildings_csv = 'data/gemeindebaubeschreibungen.csv'
buildings = pd.read_csv(buildings_csv, encoding='latin1', delimiter=';')

# %%
def clean_address(row):
    try:
        # Split into two parts: "1100 Wien" and the repeated street name
        parts = row.split(",", 1)
        if len(parts) != 2:
            return row  # if format is unexpected, return as-is

        prefix = parts[0].strip()
        street = parts[1].strip().split()  # split into words

        # Keep only the first occurrence of each word (preserving order)
        seen = set()
        deduped_street = []
        for word in street:
            if word not in seen:
                seen.add(word)
                deduped_street.append(word)

        return f"{prefix}, {' '.join(deduped_street)}"
    except Exception as e:
        print(f"Cleaning failed for: {row} — {e}")
        return row

# %%
buildings["clean_address"] = buildings["Adresse"].apply(clean_address)
buildings.head(3)
# Out:
#                           Hofname  \
# 0  Per-Albin-Hansson-Siedlung-Ost
# 1            Rudolf-Hitzinger-Hof
# 2                Großfeldsiedlung
#
#                                             Adresse  Baujahr von  Baujahr bis  \
# 0    1100 Wien, Jura-Soyfer-Gasse Jura-Soyfer-Gasse       1970.0       1974.0
# 1  1210 Wien, Leopoldauer Straße Leopoldauer Straße       1969.0       1971.0
# 2    1210 Wien, St.-Michael-Gasse St.-Michael-Gasse       1966.0       1971.0
#
#    Baujahr um                                          Architekt Kunst am Bau  \
# 0         NaN        Hermann Kutschera, Peter Payer, Oskar Payer           ja
# 1         NaN                      Friedrich Lang, Ernst Plojhar         nein
# 2         NaN  Peter Payer, Heinrich Matha, Oskar Payer, Matt...           ja
#
#    Letzte Sanierung von  Letzte Sanierung bis  Wohnungen  Lokale  \
# 0                   NaN                   NaN       4289      25
# ...

# %%
social_housing = buildings[['Hofname','clean_address' , 'Wohnungen', 'Lokale']]
type(social_housing)
social_housing.to_csv("dataframes/social_housing.csv", index=False)

# %%
print(len(social_housing))
print(social_housing['Wohnungen'].sum())
# Minimum Wohnungen
min_idx = social_housing['Wohnungen'].idxmin()
print("Wohnungen Min:", social_housing.loc[min_idx, 'Wohnungen'],
      "| clean_address:", social_housing.loc[min_idx, 'clean_address'],
      "| Hofname:", social_housing.loc[min_idx, 'Hofname'])

# Maximum Wohnungen
max_idx = social_housing['Wohnungen'].idxmax()
print("Wohnungen Max:", social_housing.loc[max_idx, 'Wohnungen'],
      "| clean_address:", social_housing.loc[max_idx, 'clean_address'],
      "| Hofname:", social_housing.loc[max_idx, 'Hofname'])

social_housing.head(3)
# Out:
# 1636
# 210984
# Wohnungen Min: 0 | clean_address: 1120 Wien, Aichholzgasse | Hofname: Aichholzgasse 52
# Wohnungen Max: 5525 | clean_address: 1210 Wien, St.-Michael-Gasse | Hofname: Großfeldsiedlung
#                           Hofname                  clean_address  Wohnungen  \
# 0  Per-Albin-Hansson-Siedlung-Ost   1100 Wien, Jura-Soyfer-Gasse       4289
# 1            Rudolf-Hitzinger-Hof  1210 Wien, Leopoldauer Straße        284
# 2                Großfeldsiedlung   1210 Wien, St.-Michael-Gasse       5525
#
#    Lokale
# 0      25
# 1       7
# 2      41

# %%
# Count how many Wohnugen are 0
zero_count = (social_housing['Wohnungen'] == 0).sum()
print("Number of Wohnungen = 0:", zero_count)

# Filter out rows with Wohnungen == 0
non_zero_df = social_housing[social_housing['Wohnungen'] > 0]

# Find minimum among non-zero values
min_idx_nz = non_zero_df['Wohnungen'].idxmin()
print("Min Wohnungen (excluding 0):", non_zero_df.loc[min_idx_nz, 'Wohnungen'],
      "| clean_address:", non_zero_df.loc[min_idx_nz, 'clean_address'],
      "| Hofname:", non_zero_df.loc[min_idx_nz, 'Hofname'])
# Out:
# Number of Wohnungen = 0: 11
# Min Wohnungen (excluding 0): 1 | clean_address: 1090 Wien, Säulengasse | Hofname: Säulengasse 18

# %%
# Define the polygon for the admin boundary of the 1st district of Bp.
admin_poly = admin_city.geometry.values[0]

# Download building footprints within the administrative boundary
residential = ox.features_from_polygon(admin_poly, tags = {"building": ["apartment", 'terrace', "detached", "annexe", "house", "residential", "semidetached_house"]})

print("Number of total buildings:", len(residential))

# Create a plot to visualize the admin boundary and building footprints
f, ax = plt.subplots(1, 1, figsize=(8, 8))

# Plot the administrative boundary
admin_city.plot(ax=ax, color='none', edgecolor='k')

# Plot the building footprints
residential.plot(ax=ax, 
                cmap = 'Greys', 
                edgecolor='black', 
                alpha=0.7, 
                linewidth = 0.5)

# Customize the plot
ax.axis('off')
plt.show()
# Out:
# Number of total buildings: 29638

# %%
print(social_housing.dtypes)
# Out:
# Hofname          object
# clean_address    object
# Wohnungen         int64
# Lokale            int64
# dtype: object

# %%
# If social_housing is a filtered view, make a safe copy
social_housing_copy = social_housing.copy()

# %%
# Download only address-tagged nodes from OpenStreetMap for Vienna
tags = {"addr:street": True, "addr:housenumber": True}
osm_data = ox.features_from_place("Vienna, Austria", tags)

# Filter out rows with missing street or housenumber info
osm_addrs = osm_data[["addr:street", "addr:housenumber", "geometry"]].dropna()

# Ensure proper coordinate system
osm_addrs = osm_addrs.to_crs("EPSG:4326")
# Out:
# /opt/anaconda3/envs/geo/lib/python3.13/site-packages/osmnx/features.py:294: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   polygon = gdf_place["geometry"].unary_union

# %%
social_housing_copy["addr_key"] = social_housing_copy["clean_address"].str.lower().str.strip()
osm_addrs["addr_key"] = (
    osm_addrs["addr:street"].str.lower().str.strip() + " " +
    osm_addrs["addr:housenumber"].astype(str).str.strip()
)

# %%
#!pip install rapidfuzz

# %%
from rapidfuzz import process

# Build a dictionary: OSM addr_key → geometry
osm_lookup = dict(zip(osm_addrs["addr_key"], osm_addrs["geometry"]))

def get_best_match(addr):
    if pd.isna(addr):
        return None
    match, score, _ = process.extractOne(addr, list(osm_lookup.keys()))
    if score > 85:
        return osm_lookup[match]
    return None

# Apply matching
social_housing_copy["geometry"] = social_housing_copy["addr_key"].apply(get_best_match)

# %%
# Drop rows where no match found (no geometry)
social_housing_copy = social_housing_copy.dropna(subset=["geometry"])

# Convert to proper GeoDataFrame
social_housing_gdf = gpd.GeoDataFrame(social_housing_copy, geometry="geometry", crs="EPSG:4326")
print(len(social_housing_gdf))
# Out:
# 1622

# %%
social_housing_gdf.to_file("dataframes/social_housing.geojson", driver="GeoJSON")

# %%
districts = gpd.read_file('data/vienna_districts.geojson') # districts data from GIS course hw2
census_boundaries = gpd.read_file('data/ZAEHLBEZIRKOGDPolygon.shp')
print(len(census_boundaries))
# Out:
# 250

# %%
print(admin_city.crs)
print(districts.crs)
print(census_boundaries.crs)
print(urban_green_spaces.crs)
print(urban_blue_spaces.crs)
print(social_housing_gdf.crs)
# Out:
# EPSG:4326
# EPSG:4326
# EPSG:4326
# EPSG:31256
# EPSG:31256
# EPSG:4326

# %%
admin_city = admin_city.to_crs(epsg=31256)
districts = districts.to_crs(epsg=31256)
census_boundaries = census_boundaries.to_crs(epsg=31256)
social_housing_gdf = social_housing_gdf.to_crs(epsg=31256)

# %%
# Filter out zero-Wohnungen buildings
non_zero = social_housing_gdf[social_housing_gdf['Wohnungen'] > 0]

# Get index for min and max
min_idx = non_zero['Wohnungen'].idxmin()
max_idx = non_zero['Wohnungen'].idxmax()

# Get corresponding GeoDataFrames
min_building = social_housing_gdf.loc[[min_idx]]
max_building = social_housing_gdf.loc[[max_idx]]

fig, ax = plt.subplots(figsize=(12, 8))

# Plot administrative and census boundaries
admin_city.plot(ax=ax, facecolor='none', edgecolor='black', linewidth=1.2, label="Admin Boundary")
districts.boundary.plot(ax=ax, edgecolor='black', linewidth=1, label="District Boundary")
census_boundaries.boundary.plot(ax=ax, edgecolor='orange', linewidth=0.5, label="Census Boundary")

# Plot urban green/blue spaces (transparent overlays)
urban_green_spaces.plot(ax=ax, cmap='Greens', alpha=0.4, edgecolor='darkgreen')
urban_blue_spaces.plot(ax=ax, color='blue', alpha=0.4, edgecolor='darkblue')

# Plot OSM residential buildings
#residential.plot(ax=ax, color='black', linewidth=0.7, alpha=0.7, label="OSM Residential Buildings")

# Plot social housing buildings with min and max Wohnungen
min_building.plot(ax=ax, color='red', markersize=50, label='Min Wohnungen (≠ 0)', marker='*')
max_building.plot(ax=ax, color='purple', markersize=50, label='Max Wohnungen', marker='*')
# Plot social housing points (in red, above everything else)
social_housing_gdf.plot(ax=ax, color='gray', markersize=3, label="Social Housing")

# Final styling
ax.set_title("Social Housing with UGBS", fontsize=16)
ax.axis('off')
ax.legend()
plt.savefig("output/03SocialVisuals/socialhousing_ugbs_map.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/fg/tx5hq3917p5dxc674m9h_4500000gn/T/ipykernel_38528/3569427916.py:35: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend()

# %% [markdown]
# ### Finding out the ratio of social housings

# %% [markdown]
# I have
# * apt_features_final csv file with ( "district_code", "census_district_code", "total_apartments", "no_central_heating", "central_heating", "owner_private", "owner_public", "owner_nonprofit", "owner_other") columns
# * census_boundaries shp file that has every census districts' geometry
# * social_housing csv file with ('Hofname','clean_address' , 'Wohnungen', 'Lokale') columns
# * social_housing_gdf as a geodataframe which has constructed to match buildings within osm
#
# now I want to add a column to apt_features_final that gives the ratio of social housing in that census districts.
# - social housing number in each census district should be get from either social_housing or social_housing_gdf I guess.
# - total number of apt in every census district is in apt_features_final, under total_apartments column

# %%
# Make sure census district codes are treated as strings
apt_features_final["census_district_code"] = apt_features_final["census_district_code"].astype(str).str[-4:]
# apt_features_final["zbez"] = apt_features_final["census_district_code"].str[-4:]
print(len(apt_features_final))
apt_features_final.head(3)
# Out:
# 249
#    district_code census_district_code  total_flats  no_central_heating  \
# 0          90100                 0101         2686                  94
# 1          90100                 0102          945                  31
# 2          90100                 0103         1294                  34
#
#    central_heating  owner_private  owner_public  owner_nonprofit  owner_other
# 0             2592           1271           483                4          928
# 1              914            559            33                4          349
# 2             1260            708            74                0          512

# %%
print(len(census_boundaries))
census_boundaries.head(3)
# Out:
# 250
#    BEZNR  ZBEZNR BEZ  ZBEZ      FLAECHE   UMFANG AKT_TIMEST  SE_SDO_ROW  \
# 0   22.0    19.0  22  2219  431562.4878  2963.93 2025-05-10    305665.0
# 1   19.0     9.0  19  1909  700939.3051  3670.56 2025-05-10    305666.0
# 2    9.0     2.0  09  0902  471286.9574  3510.43 2025-05-10    305667.0
#
#                                             geometry
# 0  POLYGON ((9534.781 343188.416, 9466.411 343046...
# 1  POLYGON ((419.711 344179.176, 419.451 344291.5...
# 2  POLYGON ((2280.931 343474.716, 2281.161 343474...

# %%
# Make sure both are strings with consistent formatting
apt_codes = apt_features_final["census_district_code"].astype(str).str.zfill(4)
boundary_codes = census_boundaries["ZBEZ"].astype(str).str.zfill(4)

# Find the missing code(s)
missing_codes = set(boundary_codes) - set(apt_codes)
print("Missing census district(s):", missing_codes)
# Out:
# Missing census district(s): {'0210'}

# %%
# Make sure both GeoDataFrames have the same CRS
social_housing_gdf = social_housing_gdf.to_crs(census_boundaries.crs)

# Perform spatial join to find out which census district each point belongs to
social_with_district = gpd.sjoin(
    social_housing_gdf,
    census_boundaries[["geometry", "ZBEZ"]],
    how="left",
    predicate="within"
)
print(social_with_district['ZBEZ'].nunique())
social_with_district.head(3)
# Out:
# 208
#                           Hofname                  clean_address  Wohnungen  \
# 0  Per-Albin-Hansson-Siedlung-Ost   1100 Wien, Jura-Soyfer-Gasse       4289
# 1            Rudolf-Hitzinger-Hof  1210 Wien, Leopoldauer Straße        284
# 2                Großfeldsiedlung   1210 Wien, St.-Michael-Gasse       5525
#
#    Lokale                       addr_key                     geometry  \
# 0      25   1100 wien, jura-soyfer-gasse  POINT (4456.031 334359.092)
# 1       7  1210 wien, leopoldauer straße  POINT (5407.042 346563.141)
# 2      41   1210 wien, st.-michael-gasse  POINT (7991.342 347602.813)
#
#    index_right  ZBEZ
# 0        143.0  1020
# 1         37.0  2123
# 2         77.0  2105

# %%
# Group by ZBEZ to get:
# - Number of buildings: count of Hofname
# - Total Wohnungen: sum of Wohnungen
social_summary = social_with_district.groupby("ZBEZ").agg(
    num_buildings=("Hofname", "count"),
    total_wohnungen=("Wohnungen", "sum")
).reset_index()

# Format ZBEZ with leading zeros
social_summary["ZBEZ"] = social_summary["ZBEZ"].astype(str).str.zfill(4)

# Rename for consistency (optional)
social_summary.columns = ["zbez", "num_buildings", "total_wohnungen"]

print("Number of census districts:", len(social_summary))

# Buildings
print("Buildings Min:", social_summary["num_buildings"].min(),
      "| ZBEZ:", social_summary.loc[social_summary["num_buildings"].idxmin(), "zbez"])
print("Buildings Max:", social_summary["num_buildings"].max(),
      "| ZBEZ:", social_summary.loc[social_summary["num_buildings"].idxmax(), "zbez"])
print("Buildings Mean:", round(social_summary["num_buildings"].mean(), 2))

# Wohnungen
print("Wohnungen Min:", social_summary["total_wohnungen"].min(),
      "| ZBEZ:", social_summary.loc[social_summary["total_wohnungen"].idxmin(), "zbez"])
print("Wohnungen Max:", social_summary["total_wohnungen"].max(),
      "| ZBEZ:", social_summary.loc[social_summary["total_wohnungen"].idxmax(), "zbez"])
print("Wohnungen Mean:", round(social_summary["total_wohnungen"].mean(), 2))

# Preview
print(social_summary.head())
# Out:
# Number of census districts: 208
# Buildings Min: 1 | ZBEZ: 0101
# Buildings Max: 31 | ZBEZ: 1505
# Buildings Mean: 7.69
# Wohnungen Min: 18 | ZBEZ: 0101
# Wohnungen Max: 5850 | ZBEZ: 2105
# Wohnungen Mean: 985.2
#    zbez  num_buildings  total_wohnungen
# 0  0101              1               18
# 1  0102              1               54
# 2  0105              1               44
# 3  0106              2              182
# 4  0107              1               22

# %%
# Merge into the apartment features table
#merged = apt_features_final.merge(social_counts, on="zbez", how="left")
merged = apt_features_final.merge(social_summary, left_on='census_district_code', right_on='zbez', how='outer')

# Fill in missing values (districts with no social housing)
merged["num_buildings"] = merged["num_buildings"].fillna(0)
merged["total_wohnungen"] = merged["total_wohnungen"].fillna(0)

# Ensure numeric types
merged["num_buildings"] = merged["num_buildings"].astype(int)
merged["total_wohnungen"] = merged["total_wohnungen"].astype(int)
merged["total_flats"] = pd.to_numeric(merged["total_flats"], errors='coerce').fillna(0).astype(int)

# Calculate the ratio
merged["social_housing_flat_ratio"] = round(merged["total_wohnungen"] / merged["total_flats"], 3)

# %%
print(len(merged))
merged.head(3)
# Out:
# 249
#    district_code census_district_code  total_flats  no_central_heating  \
# 0          90100                 0101         2686                  94
# 1          90100                 0102          945                  31
# 2          90100                 0103         1294                  34
#
#    central_heating  owner_private  owner_public  owner_nonprofit  owner_other  \
# 0             2592           1271           483                4          928
# 1              914            559            33                4          349
# 2             1260            708            74                0          512
#
#    zbez  num_buildings  total_wohnungen  social_housing_flat_ratio
# 0  0101              1               18                      0.007
# 1  0102              1               54                      0.057
# 2   NaN              0                0                      0.000

# %%
aptfeatures_social_census = merged
aptfeatures_social_census.drop('zbez', axis=1, inplace=True)

# %%
aptfeatures_social_census.head(3)
# Out:
#    district_code census_district_code  total_flats  no_central_heating  \
# 0          90100                 0101         2686                  94
# 1          90100                 0102          945                  31
# 2          90100                 0103         1294                  34
#
#    central_heating  owner_private  owner_public  owner_nonprofit  owner_other  \
# 0             2592           1271           483                4          928
# 1              914            559            33                4          349
# 2             1260            708            74                0          512
#
#    num_buildings  total_wohnungen  social_housing_flat_ratio
# 0              1               18                      0.007
# 1              1               54                      0.057
# 2              0                0                      0.000

# %%
# social housing ratio
print("social housing ratio Min:", aptfeatures_social_census["social_housing_flat_ratio"].min().round(3),
      "| census_district_code:", aptfeatures_social_census.loc[aptfeatures_social_census["social_housing_flat_ratio"].idxmin(), "census_district_code"])
print("social housing ratio Max:", aptfeatures_social_census["social_housing_flat_ratio"].max().round(3),
      "| census_district_code:", aptfeatures_social_census.loc[aptfeatures_social_census["social_housing_flat_ratio"].idxmax(), "census_district_code"])
print("social housing ratio Mean:", aptfeatures_social_census["social_housing_flat_ratio"].mean().round(3))
# Out:
# social housing ratio Min: 0.0 | census_district_code: 0103
# social housing ratio Max: 77.462 | census_district_code: 2130
# social housing ratio Mean: 0.502

# %%
print(type(aptfeatures_social_census))
print(len(aptfeatures_social_census))
aptfeatures_social_census.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 249
#    district_code census_district_code  total_flats  no_central_heating  \
# 0          90100                 0101         2686                  94
# 1          90100                 0102          945                  31
# 2          90100                 0103         1294                  34
#
#    central_heating  owner_private  owner_public  owner_nonprofit  owner_other  \
# 0             2592           1271           483                4          928
# 1              914            559            33                4          349
# 2             1260            708            74                0          512
#
#    num_buildings  total_wohnungen  social_housing_flat_ratio
# 0              1               18                      0.007
# 1              1               54                      0.057
# 2              0                0                      0.000

# %%
aptfeatures_social_census['census_district_code'].dtype
# Out:
# dtype('O')

# %%
aptfeatures_social_census['census_district_code'] = (
    aptfeatures_social_census['census_district_code'].astype(str).str.zfill(4)
)

# %%
aptfeatures_social_census.to_csv("dataframes/aptfeatures_social_census.csv", index=False)

# %% [markdown]
# ### Some Descriptive Stats on Social Housing

# %%
print("Min:", aptfeatures_social_census["social_housing_flat_ratio"].min())
print("Max:", aptfeatures_social_census["social_housing_flat_ratio"].max())
print("Mean:", aptfeatures_social_census["social_housing_flat_ratio"].mean())
print("Median:", aptfeatures_social_census["social_housing_flat_ratio"].median())
# Out:
# Min: 0.0
# Max: 77.462
# Mean: 0.5015502008032129
# Median: 0.106

# %%
min_row = aptfeatures_social_census.loc[aptfeatures_social_census["social_housing_flat_ratio"].idxmin()]
max_row = aptfeatures_social_census.loc[aptfeatures_social_census["social_housing_flat_ratio"].idxmax()]

print("\nDistrict with MIN Social Housing share:")
print(min_row[["census_district_code", 'district_code', "social_housing_flat_ratio", "num_buildings", 'total_wohnungen', "total_flats"]])

print("\nDistrict with MAX Social Housing share:")
print(max_row[["census_district_code", 'district_code', "social_housing_flat_ratio", "num_buildings", 'total_wohnungen', "total_flats"]])
# Out:
# District with MIN Social Housing share:
# census_district_code          0103
# district_code                90100
# social_housing_flat_ratio      0.0
# num_buildings                    0
# total_wohnungen                  0
# total_flats                   1294
# Name: 2, dtype: object
#
# District with MAX Social Housing share:
# census_district_code           2130
# district_code                 92100
# social_housing_flat_ratio    77.462
# num_buildings                     2
# total_wohnungen                1007
# total_flats                      13
# Name: 197, dtype: object

# %%
min_row_numb = aptfeatures_social_census.loc[aptfeatures_social_census["num_buildings"].idxmin()]
max_row_numb = aptfeatures_social_census.loc[aptfeatures_social_census["num_buildings"].idxmax()]

print("\nDistrict with MIN Social Housing buildings:")
print(min_row_numb[["census_district_code", 'district_code', "social_housing_flat_ratio", "num_buildings", 'total_wohnungen', "total_flats"]])

print("\nDistrict with MAX Social Housing buildings:")
print(max_row_numb[["census_district_code", 'district_code', "social_housing_flat_ratio", "num_buildings", 'total_wohnungen', "total_flats"]])
# Out:
# District with MIN Social Housing buildings:
# census_district_code          0103
# district_code                90100
# social_housing_flat_ratio      0.0
# num_buildings                    0
# total_wohnungen                  0
# total_flats                   1294
# Name: 2, dtype: object
#
# District with MAX Social Housing buildings:
# census_district_code          1505
# district_code                91500
# social_housing_flat_ratio    0.191
# num_buildings                   31
# total_wohnungen               1146
# total_flats                   6008
# Name: 126, dtype: object

# %%
# --- Min/Max for Social Housing Buildings ---
nonzero_bld = aptfeatures_social_census[aptfeatures_social_census['num_buildings'] > 0]
min_idx_bld = nonzero_bld['num_buildings'].idxmin()
max_idx_bld = aptfeatures_social_census['num_buildings'].idxmax()

print("\nDistrict with MIN Social Housing buildings (excluding 0):")
print("ZBEZ:", aptfeatures_social_census.loc[min_idx_bld, 'census_district_code'],
      "| num_buildings:", aptfeatures_social_census.loc[min_idx_bld, 'num_buildings'])

print("\nDistrict with MAX Social Housing buildings:")
print("ZBEZ:", aptfeatures_social_census.loc[max_idx_bld, 'census_district_code'],
      "| num_buildings:", aptfeatures_social_census.loc[max_idx_bld, 'num_buildings'])


# --- Min/Max for Social Housing Flats (Wohnungen) ---
nonzero_flats = aptfeatures_social_census[aptfeatures_social_census['total_wohnungen'] > 0]
min_idx_flats = nonzero_flats['total_wohnungen'].idxmin()
max_idx_flats = aptfeatures_social_census['total_wohnungen'].idxmax()

print("\nDistrict with MIN Social Housing flats (excluding 0):")
print("ZBEZ:", aptfeatures_social_census.loc[min_idx_flats, 'census_district_code'],
      "| total_wohnungen:", aptfeatures_social_census.loc[min_idx_flats, 'total_wohnungen'])

print("\nDistrict with MAX Social Housing flats:")
print("ZBEZ:", aptfeatures_social_census.loc[max_idx_flats, 'census_district_code'],
      "| total_wohnungen:", aptfeatures_social_census.loc[max_idx_flats, 'total_wohnungen'])


# --- Min/Max for All Flats (no need to exclude 0s here) ---
min_idx_all = aptfeatures_social_census['total_flats'].idxmin()
max_idx_all = aptfeatures_social_census['total_flats'].idxmax()

print("\nDistrict with MIN total flats:")
print("ZBEZ:", aptfeatures_social_census.loc[min_idx_all, 'census_district_code'],
      "| total_flats:", aptfeatures_social_census.loc[min_idx_all, 'total_flats'])

print("\nDistrict with MAX total flats:")
print("ZBEZ:", aptfeatures_social_census.loc[max_idx_all, 'census_district_code'],
      "| total_flats:", aptfeatures_social_census.loc[max_idx_all, 'total_flats'])


# --- Totals ---
print("\nTOTAL number of all flats:", aptfeatures_social_census['total_flats'].sum())
print("TOTAL number of social housing flats:", aptfeatures_social_census['total_wohnungen'].sum())
print("TOTAL number of social housing buildings:", aptfeatures_social_census['num_buildings'].sum())
# Out:
# District with MIN Social Housing buildings (excluding 0):
# ZBEZ: 0101 | num_buildings: 1
#
# District with MAX Social Housing buildings:
# ZBEZ: 1505 | num_buildings: 31
#
# District with MIN Social Housing flats (excluding 0):
# ZBEZ: 0101 | total_wohnungen: 18
#
# District with MAX Social Housing flats:
# ZBEZ: 2105 | total_wohnungen: 5850
#
# District with MIN total flats:
# ZBEZ: 2130 | total_flats: 13
#
# District with MAX total flats:
# ZBEZ: 1110 | total_flats: 12172
#
# TOTAL number of all flats: 1074967
# TOTAL number of social housing flats: 204922
# TOTAL number of social housing buildings: 1599
