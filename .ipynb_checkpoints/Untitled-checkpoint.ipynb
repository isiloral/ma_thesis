# %%
import requests

api_url = "https://www.data.gv.at/katalog/api/3/action/package_show"
dataset_id = "d0145df8-7f6d-46e1-9bc6-ee7897054104"

response = requests.get(api_url, params={"id": dataset_id})
data = response.json()["result"]

# Look through the resources for a JSON or CSV
for res in data["resources"]:
    if res["format"].lower() in ["json", "csv"]:
        print("Found resource:", res["name"])
        print("Download URL:", res["url"])
# Out:
# Found resource: WFS GetFeature (CSV) - Flächen
# Download URL: https://data.wien.gv.at/daten/geo?service=WFS&request=GetFeature&version=1.1.0&typeName=ogdwien:OEFFGRUENFLOGD&srsName=EPSG:4326&outputFormat=csv
# Found resource: WFS GetFeature (CSV) - Linien
# Download URL: https://data.wien.gv.at/daten/geo?service=WFS&request=GetFeature&version=1.1.0&typeName=ogdwien:OEFFGRUENLINGOGD&srsName=EPSG:4326&outputFormat=csv
# Found resource: WFS GetFeature (CSV) - Punkte
# Download URL: https://data.wien.gv.at/daten/geo?service=WFS&request=GetFeature&version=1.1.0&typeName=ogdwien:OEFFGRUENPKTGOGD&srsName=EPSG:4326&outputFormat=csv
# Found resource: WFS GetFeature (JSON) -  Flächen
# Download URL: https://data.wien.gv.at/daten/geo?service=WFS&request=GetFeature&version=1.1.0&typeName=ogdwien:OEFFGRUENFLOGD&srsName=EPSG:4326&outputFormat=json
# Found resource: WFS GetFeature (JSON) -  Linien
# Download URL: https://data.wien.gv.at/daten/geo?service=WFS&request=GetFeature&version=1.1.0&typeName=ogdwien:OEFFGRUENLINGOGD&srsName=EPSG:4326&outputFormat=json
# Found resource: WFS GetFeature (JSON) -  Punkte
# Download URL: https://data.wien.gv.at/daten/geo?service=WFS&request=GetFeature&version=1.1.0&typeName=ogdwien:OEFFGRUENPKTGOGD&srsName=EPSG:4326&outputFormat=json

# %%
import pandas as pd

csv_url = "https://data.wien.gv.at/daten/geo?service=WFS&request=GetFeature&version=1.1.0&typeName=ogdwien:OEFFGRUENFLOGD&srsName=EPSG:4326&outputFormat=csv"
df = pd.read_csv(csv_url)

print("Columns:")
print(df.columns)

print("\nFirst few rows:")
print(df.head())

# %%
import requests

url = "https://www.data.gv.at/katalog/api/3/action/package_show"
dataset_id = "d0145df8-7f6d-46e1-9bc6-ee7897054104"

response = requests.get(url, params={"id": dataset_id})
notes = response.json()["result"]["notes"]
print(notes)
# Out:
# Column types:
# FID                  object
# OBJECTID              int64
# SHAPE                object
# TEXT13ID             object
# F_TYP                object
# T_TEXT               object
# T_LANG               object
# O                     int64
# P                     int64
# O_UEREG               int64
# O_REGION              int64
# O_LOKAL               int64
# P_WLD                 int64
# P_WAS                 int64
# P_WIE                 int64
# P_WGT                 int64
# P_LW                  int64
# P_PK                  int64
# P_GPK                 int64
# P_GST                 int64
# P_SGR                 int64
# P_AGR                 int64
# P_RGR                 int64
# P_URB                 int64
# Q_MOB                 int64
# Q_SPI                 int64
# Q_GRI                 int64
# Q_HUN                 int64
# Q_BAB                 int64
# Q_WC                  int64
# Q_SPO                 int64
# Q_TRB                 int64
# UMFANG              float64
# FLAECHE             float64
# SE_ANNO_CAD_DATA     object
# dtype: object
#
# Unique values per column:
#  'POLYGON ((16.30870496949011 48.22281443536587, 16.309332242440117 48.22284915133408, 16.309405427323686 48.22290059776531, 16.30911911029101 48.22301322730569, 16.309170470240925 48.22308181248661, 16.308416621790975 48.223346088985345, 16.308278953340768 48.2231794009949, 16.308235452306057 48.222982944855936, 16.308252742854126 48.222867723712135, 16.308267996159117 48.22278397826037, 16.30870496949011 48.22281443536587))'
#  'POLYGON ((16.301808419257775 48.229533308287756, 16.301766394314114 48.22947708831759, 16.30422737081312 48.22895450642069, 16.305478893727628 48.22866678427215, 16.305478866540195 48.228712312279455, 16.30539472169801 48.22874741900767, 16.304947736303 48.228877419287784, 16.30474788034967 48.228972073970155, 16.30433240657205 48.22915828787105, 16.304006350271553 48.22927061207602, 16.303806526634386 48.22933013593766, 16.303401618024317 48.22940028066589, 16.30305984525603 48.2294389659901, 16.302767464300402 48.229422558887975, 16.302465727205828 48.229410689862675, 16.301808419257775 48.229533308287756))'
#  'POLYGON ((16.334833407754807 48.22715579087256, 16.33479997319717 48.22710600598782, 16.334734078534375 48.227112724018745, 16.334675800638845 48.22706793720827, 16.334637308440325 48.22701199907047, 16.334610931540954 48.226895267111665, 16.334534753787878 48.22682837382789, 16.334468131798126 48.22677808386034, 16.334481055203646 48.22670110233262, 16.334579578569375 48.22665442904288, 16.33468808039963 48.22665745936223, 16.334820393288236 48.22659813016696, 16.334798967269347 48.226555057031895, 16.33488362719338 48.22650271760855, 16.335024336643688 48.22650668054941, 16.335117768770886 48.22646478483037, 16.335156178533243 48.2264025360905, 16.33526896778882 48.226336077306364, 16.335358337048905 48.22631926067333, 16.335403694251738 48.22633657286278, 16.33568578117909 48.226820238910854, 16.334833407754807 48.22715579087256))']
# TEXT13ID: ['Währinger Pa*' 'Türkenschanz*' 'Kongreßpark' 'Josef-Kaderk*'
#  'Ebner-Eschen*']
# F_TYP: ['L' 'R' 'U']
# T_TEXT: ['Währinger Park' 'Türkenschanzplatz' 'Kongreßpark/Kainzga'
#  'Josef-Kaderka-Park' 'Ebner-Eschenbach-Park']
# T_LANG: ['Währinger Park' 'Türkenschanzplatz' 'Kainzgasse' 'Josef-Kaderka-Park'
#  'Ebner-Eschenbach-Park']
# O: [  1  10 100]
# P: [      100000            1 100000000000       110000   1000110000]
# O_UEREG: [0 1]
# O_REGION: [0 1]
# O_LOKAL: [ 1  0 10]
# P_WLD: [0 1]
# P_WAS: [0 1]
# P_WIE: [0 1]
# P_WGT: [0 1]
# P_LW: [0 1]
# P_PK: [1 0]
# P_GPK: [0 1]
# P_GST: [0 1]
# P_SGR: [0 1]
# P_AGR: [0 1]
# P_RGR: [0 1]
# P_URB: [0 1]
# Q_MOB: [0]
# Q_SPI: [1 0]
# Q_GRI: [0 1]
# Q_HUN: [1 0]
# Q_BAB: [0 1]
# Q_WC: [1 0 2]
# Q_SPO: [1245    0   12    2  125]
# Q_TRB: [1 0]
# UMFANG: [1460.94145058  310.90019614  249.28487584  596.4859502   285.00613316]
# FLAECHE: [57020.13190308  2002.71599346  3243.48478905  5086.63643454
#   4592.97040017]
# SE_ANNO_CAD_DATA: ['[B@2703662e' '[B@7b2e3749' '[B@20709f8b' '[B@7c7f579b' '[B@40716c2c']
